# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhila-AIML/IRS-lab/blob/main/IRS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Representing of a text documents in vector space similarity between two documents

# %%
frtificial intelligence and machine learning are widely used to make smart applications based on data."
documents=[doc1,doc2]
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(documents)
similarity_score=cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity om sklearn.metrics.pairwise import cosine_similarity
doc1="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2="Arbetween Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 0.4039

# %%
from skleran.metrics.pairwise import cosine_similarity
doc1="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
documents=[doc1,doc2]
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(documents)
similarity_score=cosine_similarityfrom sklearn.feature_extraction.text import TfidfVectorizer
doc1(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Dfrom sklearn.metrics.pairwise import cosine_similarity
ocument 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 1.0000

# %%
from sklearn.metrics.pairwise import cosine_similarity
doc1="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc2="Machine learning is a branch of artificial intelligence that focuses on building applications that learn from data."
doc3="Artificial Intelligence is a subset of Machine learning."
documents=[doc1,doc2]
vectorizer=TfidfVectorizer(stop_words='english')
tfidf_matrix=vectorizer.fit_transform(documents)
similarity_score=cosine_similarity(tfidf_matrix[0:1],tfidf_matrix[1:2])[0][0]
print("Cosine Similarity between Document 1 and Document 2:")
print(f"{similarity_score:.4f}")
# Out:
# Cosine Similarity between Document 1 and Document 2:
# 1.0000
